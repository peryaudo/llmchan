# %%
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
)
import torch

# %%
model = AutoModelForCausalLM.from_pretrained("train4000k-pretrained", device_map={"": 0}, torch_dtype=torch.float16)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
tokenizer = AutoTokenizer.from_pretrained("rinna/youri-7b")
tokenizer.pad_token = tokenizer.eos_token

# %%
def generate(topic):
    text = f"質問: 匿名掲示板5ちゃんねるの投稿者として、以下のニュースにコメントしてください。\nニュース: {topic}\nコメント: "
    token_ids = tokenizer.encode(text, add_special_tokens=False, return_tensors="pt")
    
    with torch.no_grad():
        output_ids = model.generate(
            token_ids.to(model.device),
            max_new_tokens=200,
            do_sample=True,
            pad_token_id=tokenizer.pad_token_id,
            bos_token_id=tokenizer.bos_token_id,
            eos_token_id=tokenizer.eos_token_id
        )
    
    output = tokenizer.decode(output_ids.tolist()[0])[len(tokenizer.decode(token_ids.tolist()[0])):]
    print(output)

# %%
def generate_n(topic, n):
    for i in range(n):
        generate(topic)

# %%
generate_n("羽田空港近くでバイクが縁石に接触、後ろに乗っていた男子高校生が死亡…無免許運転", 20)
# Out:
# 検挙率上げたって抑止薬にならんだろ？
# 検挙率が上がれば免許更新10年とかされて単刀直入に費用と手間掛かるようにすれば良いだけだろ？
# 違反取り締まりばっかりしないで少しは事故撲滅に資本を回せよバカ役人どもめが？��������������������������������������������������������
# このスレでもバカスレｗ自己スレ�������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������
# 自身で罪をチョイスするのなｗ
# 何が罪重視じゃｗｗ
# どう考えても泣きの方一択orz
# アホかとｗｗｗｗ（´Д｀υ)ξ‐/しまりな
# 罪なんて税率のいいもんから先に選んでほしいね♪軽トラで110キロにしか
# いかねｗｗｗｗｗｗｗｗ考えられんｗｗｗｗｗｗｗｗｗｗ
# そういえば精神病棟で鍵に指貫けて自殺した爺さんがいたな
# 厳しい精神病棟でも何かしら自分側に有利な物や病棟からの物の損傷や取り外しで自殺自殺やって自殺できると評判だったらしいよ精神病棟はw笑ったよwあちゃあw何でも有りだわw笑ったw笑ったw無限w笑ったw笑ったw精神病棟爺さ
# これは自然の摂理だよ
# 不浄と洗浄
# 汚臭と純白
# これが自然のまじわりで出来る。
# 差別せず、抹殺せず、秩序に返せば、自然とまた新しいものが生まれる。
# これが自然の営みだよ。
# 自然は公平だよ。それが過渡期。かしこ差す。かか様す。ｓｄｔはこのさいのからｓｄｔじゃね？�����������������������������
# 自公でもだめになってるぞw
# 規制を緩めて移民受け入れるって話もあるしw
# 民進共産は無理だろw
# 創価は移民受け入れるから競合して共倒れだろw
# お前が何を読めばいいのかすら、分からん。
# さすがだw 粘着ストーキング野郎wだなww
# ...

# %%
generate_n("石川県能登地方でM5.5の地震　輪島市で震度5強　津波の心配なし", 20)
# Out:
# 今はスマホで大体分かるからなあ
# 役場に電話しても出るだけの暇な職員か、出たら無感情な嫌味抵抗専門受付とかが多いしなあ。
# こっちも仕事中なんだがなあ。
# ツイッター見てこいって感じやな。頼むからw
# .･ ﾟ　彡三ﾞ:艸ﾞｼ
# .∩-艸∩ ･.∩-艸-　 ﾖ!ﾖ*
# .彡.⌒ ミレレ
# .彡/ (
# ありがと 震度5強は酷い＼(^o^)／
# 3.11の時 震度5 ＠茨城県 だったけど 震度4と同じように 何時間も ビクビク揺れてたから 印象として 酷いという記憶が、
# 一気に 30ｍ近い津波が来たと 勉強になったよ ありがとう＼(^o^)�����������������������������������������������
# またか
# 歴史的にいえば大地震の始まり
# だが適当な地震の後に大地震は来ない
# これが原則かもしれない
# 今年の夏は大変なのかもしれないな。冷夏だし
# 日本は地震の調子が、かなり変だな。覚悟しとけよ。(´・ω・｀)　熊野＠１週間豚箱だった男。 ( ( 彡　)
# ﾐ （
# . |ﾐ ζ∧＿
# (ﾐﾐ
# .⊂とヽ∩　湧いてきそ
# 震源深いがかなり深いからな
# 震度５強という割には響いてるように感じなかったな
# 震度５強だと６強クラスの揺れでも違和感無くて震源深くて助かった
# マグ、どこも地震が頻発してるね、熊本あたりはもうヤバイかもなぁ・・・. . .
# （−人-）����������������������������������������������
# 被害が最小限であります様に
# 平和であります様に
# みんな祈ったよね
# なのに何故、、、アンビリーバボーやめてま
# そんな魂の叫びが聞こえた気がした。ごめんね
# おそらく私はまだ励ましている。いや、頼んでるんだw　ありがとな。 もの</s>
# 地球規模だと地震とか雷とか全然アリだよ地球システムは
# 日本の地震とか自然災害は洪水とかがひどいからその規模が少ない
# 海とか外と関係してるし
# そんなイメージだ確かめてはないけどねwどうかな?w(どーでもいいか(o+゜ｖ私達が暮してるのは地球だしねw)v:＋o)v:Df)v:E/j)v:i:Df)v:d:O)v:Bf)v:O:g)v:j)v:
# ...
